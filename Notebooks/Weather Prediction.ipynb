# %% [markdown]
# **Importar librerias**

# %%
import pandas as pd
import streamlit as st
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Cargar csv

# %%
df = pd.read_csv('../Data/raw/weather_prediction_dataset.csv', header = 0)

# %% [markdown]
# ### Inspecciono la cabecera

# %%
df.shape[0]
# Out:
# 3654

# %% [markdown]
# ###  El dataset tiene 165 columnas, pero son los mismos valores para ciudades distintas, porlo que quizas se pueda hacer una agrupación

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# 2                    0.50                 0.00             3.7
# 3                    0.63                 0.35             6.9
# 4                    0.51                 0.07             3.7
#
#    BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 0              2.9             1.6  ...                -9.3
# ...

# %%
df
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1                  8            0.89          1.0286
# 1     20000102      1                  8            0.87          1.0318
# 2     20000103      1                  5            0.81          1.0314
# 3     20000104      1                  7            0.79          1.0262
# 4     20000105      1                  5            0.90          1.0246
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12                  7            0.82          1.0084
# 3650  20091229     12                  7            0.92          1.0028
# 3651  20091230     12                  8            0.92          0.9979
# 3652  20091231     12                  7            0.93          0.9958
# 3653  20100101      1                  8            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %% [markdown]
# ### Target predecir las temperaturas de cada ciuidad y la categoria del tiempo que va a hacer

# %%
print(df.columns)
# Out:
# Index(['DATE', 'MONTH', 'BASEL_cloud_cover', 'BASEL_humidity',
#        'BASEL_pressure', 'BASEL_global_radiation', 'BASEL_precipitation',
#        'BASEL_sunshine', 'BASEL_temp_mean', 'BASEL_temp_min',
#        ...
#        'STOCKHOLM_temp_min', 'STOCKHOLM_temp_max', 'TOURS_wind_speed',
#        'TOURS_humidity', 'TOURS_pressure', 'TOURS_global_radiation',
#        'TOURS_precipitation', 'TOURS_temp_mean', 'TOURS_temp_min',
#        'TOURS_temp_max'],
#       dtype='object', length=165)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3654 entries, 0 to 3653
# Columns: 165 entries, DATE to TOURS_temp_max
# dtypes: float64(150), int64(15)
# memory usage: 4.6 MB

# %%
df.describe()
# Out:
#                DATE        MONTH  BASEL_cloud_cover  BASEL_humidity  \
# count  3.654000e+03  3654.000000        3654.000000     3654.000000
# mean   2.004568e+07     6.520799           5.418446        0.745107
# std    2.874287e+04     3.450083           2.325497        0.107788
# min    2.000010e+07     1.000000           0.000000        0.380000
# 25%    2.002070e+07     4.000000           4.000000        0.670000
# 50%    2.004567e+07     7.000000           6.000000        0.760000
# 75%    2.007070e+07    10.000000           7.000000        0.830000
# max    2.010010e+07    12.000000           8.000000        0.980000
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# count     3654.000000             3654.000000          3654.000000
# mean         1.017876                1.330380             0.234849
# std          0.007962                0.935348             0.536267
# min          0.985600                0.050000             0.000000
# ...

# %%
df_ciudad = pd.read_csv("../Data/processed/df_ciudad_filtrada.csv")
df_ciudad.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# 2                    0.50                 0.00             3.7
# 3                    0.63                 0.35             6.9
# 4                    0.51                 0.07             3.7
#
#    BASEL_temp_mean  BASEL_temp_min  BASEL_temp_max
# 0              2.9             1.6             3.9
# 1              3.6             2.7             4.8
# ...

# %%
df_ciudad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3654 entries, 0 to 3653
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DATE                    3654 non-null   int64
#  1   MONTH                   3654 non-null   int64
#  2   BASEL_cloud_cover       3654 non-null   int64
#  3   BASEL_humidity          3654 non-null   float64
#  4   BASEL_pressure          3654 non-null   float64
#  5   BASEL_global_radiation  3654 non-null   float64
#  6   BASEL_precipitation     3654 non-null   float64
#  7   BASEL_sunshine          3654 non-null   float64
#  8   BASEL_temp_mean         3654 non-null   float64
#  9   BASEL_temp_min          3654 non-null   float64
#  10  BASEL_temp_max          3654 non-null   float64
# dtypes: float64(8), int64(3)
# memory usage: 314.1 KB

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

df_ciudad['DATE'] = pd.to_datetime(df_ciudad['DATE'], format='%Y%m%d')
df_ciudad['month'] = df_ciudad['DATE'].dt.month
df_ciudad['dayofyear'] = df_ciudad['DATE'].dt.dayofyear
df_ciudad['weekday'] = df_ciudad['DATE'].dt.weekday

X = df_ciudad[['month', 'dayofyear', 'weekday']]
y = df_ciudad.iloc[:, 5:13].values


X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)


modelo = RandomForestRegressor()
modelo.fit(X, y)
y_pred = modelo.predict(X_test)

r2 = r2_score(y_test, y_pred)

print(r2)
# Out:
# 0.809883134651831

# %%
entrada = [[7, 200, 3]]

# Predecir
pred = modelo.predict(entrada)[0]
print(pred[0],[1],[2],[3])
# Out:
# 2.171960714285712 [1] [2] [3]
# c:\Users\34666\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
import joblib

joblib.dump(modelo, "../Models/modelo_regressor.pkl")
# Out:
# ['../Models/modelo_regressor.pkl']
